# %% [markdown]
# Here are the features we are adding:
# - price related features (can use original data)
#   - daily closing price
#   - returns
#   - log returns
#   - volatility
#
# - macroeconomic indidactors (from yahoo finance api)
#   - P/E
#   - P/B
#   - Dividend Yield
#
# - sector indicators (yahoo finance api)
#   - beta
#   - which sector it's in
#
# - Momentum indicators (can be calculated using original data)
#   - average moving ratios (different days)
#
# - Co movement stuff
#   - moving window correlation between stock pairs, to help identify stocks that are moving together, ideally using the same sector to have less combinations
#   - normalized distance metric to help guage similarity
#   - rmean reverting realtionship useful for pairs that are more related
#   - rolling mean and rolling std

# %%
import os
import pandas as pd

## CHANGE TO YOUR OWN OUTPUT
input_folder = '/Users/wesleylu/Desktop/CS4641/dataset/stock_txt'
output_folder = '/Users/wesleylu/Desktop/CS4641/dataset/stock_csv'

os.makedirs(output_folder, exist_ok=True)
for filename in os.listdir(input_folder):
    if filename.endswith(".txt"):
        file_path = os.path.join(input_folder, filename)
        if os.path.getsize(file_path) == 0:
            print(f"Skipping {filename} as it is empty.")
            continue
        try:
            df = pd.read_csv(file_path, delimiter='\t')
        except pd.errors.EmptyDataError:
            print(f"Error reading {filename} with tab delimiter; trying comma.")
            try:
                df = pd.read_csv(file_path, delimiter=',')
            except pd.errors.EmptyDataError:
                print(f"Error reading {filename}; could not parse file. Skipping.")
                continue
        
        csv_filename = os.path.splitext(filename)[0] + ".csv"
        csv_path = os.path.join(output_folder, csv_filename)
        df.to_csv(csv_path, index=False)
        print(f"Converted {filename} to {csv_filename}")

print("Conversion completed.")
# Out:
# Converted iba.us.txt to iba.us.csv
# Converted wpz.us.txt to wpz.us.csv
# Converted opnt.us.txt to opnt.us.csv
# Converted indf.us.txt to indf.us.csv
# Converted flic.us.txt to flic.us.csv
# Converted nbhc.us.txt to nbhc.us.csv
# Converted ncs.us.txt to ncs.us.csv
# Converted grvy.us.txt to grvy.us.csv
# Converted lgcyo.us.txt to lgcyo.us.csv
# Converted eqco.us.txt to eqco.us.csv
# Converted gpk.us.txt to gpk.us.csv
# Converted wti.us.txt to wti.us.csv
# Converted dyn_a.us.txt to dyn_a.us.csv
# Converted cstr.us.txt to cstr.us.csv
# Converted mygn.us.txt to mygn.us.csv
# Converted cor_a-cl.us.txt to cor_a-cl.us.csv
# Converted jmu.us.txt to jmu.us.csv
# Converted jpem.us.txt to jpem.us.csv
# Converted kelya.us.txt to kelya.us.csv
# Converted wbig.us.txt to wbig.us.csv
# Converted eemx.us.txt to eemx.us.csv
# Converted nycb.us.txt to nycb.us.csv
# Converted elp.us.txt to elp.us.csv
# Converted aieq.us.txt to aieq.us.csv
# Converted axas.us.txt to axas.us.csv
# Converted cphi.us.txt to cphi.us.csv
# Converted thr.us.txt to thr.us.csv
# Converted nxeow.us.txt to nxeow.us.csv
# Converted vrsk.us.txt to vrsk.us.csv
# Converted abil.us.txt to abil.us.csv
# Converted evep.us.txt to evep.us.csv
# Converted srlp.us.txt to srlp.us.csv
# Converted www.us.txt to www.us.csv
# Converted nnvc.us.txt to nnvc.us.csv
# Converted exr.us.txt to exr.us.csv
# Converted feye.us.txt to feye.us.csv
# Converted rbcaa.us.txt to rbcaa.us.csv
# Converted enrj.us.txt to enrj.us.csv
# Converted mlnt.us.txt to mlnt.us.csv
# Converted avt.us.txt to avt.us.csv
# Converted gazb.us.txt to gazb.us.csv
# Converted dxr.us.txt to dxr.us.csv
# Converted gdi.us.txt to gdi.us.csv
# Converted ngvt.us.txt to ngvt.us.csv
# Converted irix.us.txt to irix.us.csv
# Converted pay.us.txt to pay.us.csv
# Converted pfbx.us.txt to pfbx.us.csv
# Converted hyxu.us.txt to hyxu.us.csv
# Converted nlnk.us.txt to nlnk.us.csv
# Converted ivc.us.txt to ivc.us.csv
# Converted mxe.us.txt to mxe.us.csv
# Converted osb.us.txt to osb.us.csv
# Converted txrh.us.txt to txrh.us.csv
# Converted mx.us.txt to mx.us.csv
# Converted smmd.us.txt to smmd.us.csv
# Converted mnro.us.txt to mnro.us.csv
# Converted hdez.us.txt to hdez.us.csv
# Converted pgz.us.txt to pgz.us.csv
# Converted l.us.txt to l.us.csv
# Converted jasn.us.txt to jasn.us.csv
# Converted gfy.us.txt to gfy.us.csv
# Converted eim.us.txt to eim.us.csv
# Converted bll.us.txt to bll.us.csv
# Converted pci.us.txt to pci.us.csv
# Converted born.us.txt to born.us.csv
# Converted ribtw.us.txt to ribtw.us.csv
# Converted cizn.us.txt to cizn.us.csv
# Converted usau.us.txt to usau.us.csv
# Converted brkr.us.txt to brkr.us.csv
# Converted tmo.us.txt to tmo.us.csv
# Converted nee_j.us.txt to nee_j.us.csv
# Converted clns_b.us.txt to clns_b.us.csv
# Converted cmct.us.txt to cmct.us.csv
# Converted mmi.us.txt to mmi.us.csv
# Converted stor.us.txt to stor.us.csv
# Converted clct.us.txt to clct.us.csv
# Converted fuv.us.txt to fuv.us.csv
# Converted pdlb.us.txt to pdlb.us.csv
# Converted oilb.us.txt to oilb.us.csv
# Converted tgen.us.txt to tgen.us.csv
# Converted fat.us.txt to fat.us.csv
# Converted cma-ws.us.txt to cma-ws.us.csv
# Converted he.us.txt to he.us.csv
# Converted wyde.us.txt to wyde.us.csv
# Converted cor.us.txt to cor.us.csv
# Converted imkta.us.txt to imkta.us.csv
# Converted nep.us.txt to nep.us.csv
# Converted ddbi.us.txt to ddbi.us.csv
# Converted flks.us.txt to flks.us.csv
# Converted emxc.us.txt to emxc.us.csv
# Converted nac.us.txt to nac.us.csv
# Converted dfin.us.txt to dfin.us.csv
# Converted psx.us.txt to psx.us.csv
# Converted atacu.us.txt to atacu.us.csv
# Converted joe.us.txt to joe.us.csv
# Converted hdb.us.txt to hdb.us.csv
# Converted agn_a.us.txt to agn_a.us.csv
# Converted rexr_a.us.txt to rexr_a.us.csv
# Converted jhd.us.txt to jhd.us.csv
# Converted wpcs.us.txt to wpcs.us.csv
# Converted ath.us.txt to ath.us.csv
# Converted tapr.us.txt to tapr.us.csv
# Converted yrcw.us.txt to yrcw.us.csv
# Converted hcc.us.txt to hcc.us.csv
# Converted sivb.us.txt to sivb.us.csv
# Converted fncf.us.txt to fncf.us.csv
# Converted igro.us.txt to igro.us.csv
# Converted coll.us.txt to coll.us.csv
# Converted pty.us.txt to pty.us.csv
# Converted dmrc.us.txt to dmrc.us.csv
# Converted kmpr.us.txt to kmpr.us.csv
# Converted kw.us.txt to kw.us.csv
# Converted ceco.us.txt to ceco.us.csv
# Converted asb-ws.us.txt to asb-ws.us.csv
# Converted sfst.us.txt to sfst.us.csv
# Converted chs.us.txt to chs.us.csv
# Converted tslx.us.txt to tslx.us.csv
# Converted umc.us.txt to umc.us.csv
# Converted eia.us.txt to eia.us.csv
# Converted num.us.txt to num.us.csv
# Converted fult.us.txt to fult.us.csv
# Converted fele.us.txt to fele.us.csv
# Converted evtc.us.txt to evtc.us.csv
# Converted emr.us.txt to emr.us.csv
# Converted jbht.us.txt to jbht.us.csv
# Converted ofix.us.txt to ofix.us.csv
# Converted achn.us.txt to achn.us.csv
# Converted cbrl.us.txt to cbrl.us.csv
# Converted odfl.us.txt to odfl.us.csv
# Converted bracr.us.txt to bracr.us.csv
# Converted zlab.us.txt to zlab.us.csv
# Converted nao.us.txt to nao.us.csv
# Converted induw.us.txt to induw.us.csv
# Converted idn.us.txt to idn.us.csv
# Converted ggzr.us.txt to ggzr.us.csv
# Converted heww.us.txt to heww.us.csv
# Converted ctso.us.txt to ctso.us.csv
# Skipping pbio.us.txt as it is empty.
# Converted fqal.us.txt to fqal.us.csv
# Converted fax.us.txt to fax.us.csv
# Converted cnxn.us.txt to cnxn.us.csv
# Converted hi.us.txt to hi.us.csv
# Converted dlbr.us.txt to dlbr.us.csv
# Converted psmm.us.txt to psmm.us.csv
# Converted sncr.us.txt to sncr.us.csv
# Converted lscc.us.txt to lscc.us.csv
# Converted isr.us.txt to isr.us.csv
# Converted lyg.us.txt to lyg.us.csv
# Converted aezs.us.txt to aezs.us.csv
# Converted gek.us.txt to gek.us.csv
# Converted nvs.us.txt to nvs.us.csv
# Converted afi.us.txt to afi.us.csv
# Converted afsd.us.txt to afsd.us.csv
# Converted opp.us.txt to opp.us.csv
# Converted hcci.us.txt to hcci.us.csv
# Converted gddy.us.txt to gddy.us.csv
# Converted ghyg.us.txt to ghyg.us.csv
# Converted ipoa-ws.us.txt to ipoa-ws.us.csv
# Converted gch.us.txt to gch.us.csv
# Converted loxo.us.txt to loxo.us.csv
# Converted ibkcp.us.txt to ibkcp.us.csv
# Converted mchp.us.txt to mchp.us.csv
# Converted bsjp.us.txt to bsjp.us.csv
# Converted ntc.us.txt to ntc.us.csv
# Converted rnlc.us.txt to rnlc.us.csv
# Converted szc.us.txt to szc.us.csv
# Converted vlrs.us.txt to vlrs.us.csv
# Converted vpv.us.txt to vpv.us.csv
# Converted ivr_a.us.txt to ivr_a.us.csv
# Converted hbm.us.txt to hbm.us.csv
# Converted dtla_.us.txt to dtla_.us.csv
# Converted imom.us.txt to imom.us.csv
# Converted pgre.us.txt to pgre.us.csv
# Converted nhtc.us.txt to nhtc.us.csv
# Converted czr.us.txt to czr.us.csv
# Converted eqgp.us.txt to eqgp.us.csv
# Converted comb.us.txt to comb.us.csv
# Converted gtt.us.txt to gtt.us.csv
# Converted ngl.us.txt to ngl.us.csv
# Converted ibm.us.txt to ibm.us.csv
# Converted zyme.us.txt to zyme.us.csv
# Converted flio.us.txt to flio.us.csv
# Converted stlru.us.txt to stlru.us.csv
# Converted anss.us.txt to anss.us.csv
# Converted ubsi.us.txt to ubsi.us.csv
# Converted cnp.us.txt to cnp.us.csv
# Converted sofo.us.txt to sofo.us.csv
# Converted gaia.us.txt to gaia.us.csv
# Converted wlkp.us.txt to wlkp.us.csv
# Converted sjr.us.txt to sjr.us.csv
# Converted mt.us.txt to mt.us.csv
# Converted osn.us.txt to osn.us.csv
# Converted gamr.us.txt to gamr.us.csv
# Converted sna.us.txt to sna.us.csv
# Converted xrm.us.txt to xrm.us.csv
# Converted marps.us.txt to marps.us.csv
# Converted hcapz.us.txt to hcapz.us.csv
# Converted fisk.us.txt to fisk.us.csv
# Converted fund.us.txt to fund.us.csv
# Converted ancb.us.txt to ancb.us.csv
# Converted asmb.us.txt to asmb.us.csv
# Converted fmnb.us.txt to fmnb.us.csv
# Converted avx.us.txt to avx.us.csv
# Converted mlnx.us.txt to mlnx.us.csv
# Converted deck.us.txt to deck.us.csv
# Converted vsh.us.txt to vsh.us.csv
# Converted pnfp.us.txt to pnfp.us.csv
# Converted has.us.txt to has.us.csv
# Converted aehr.us.txt to aehr.us.csv
# Converted ahp_b.us.txt to ahp_b.us.csv
# Converted iagg.us.txt to iagg.us.csv
# Converted lb.us.txt to lb.us.csv
# Converted pbmd.us.txt to pbmd.us.csv
# Converted cof.us.txt to cof.us.csv
# Converted ent.us.txt to ent.us.csv
# Converted bku.us.txt to bku.us.csv
# Converted rpxc.us.txt to rpxc.us.csv
# Converted fivn.us.txt to fivn.us.csv
# Converted web.us.txt to web.us.csv
# Converted ges.us.txt to ges.us.csv
# Converted pdp.us.txt to pdp.us.csv
# Converted lvin.us.txt to lvin.us.csv
# Converted fxep.us.txt to fxep.us.csv
# Converted ahpi.us.txt to ahpi.us.csv
# Converted tast.us.txt to tast.us.csv
# Converted achv.us.txt to achv.us.csv
# Converted fro.us.txt to fro.us.csv
# Converted ftxn.us.txt to ftxn.us.csv
# Converted wbkc.us.txt to wbkc.us.csv
# Converted jack.us.txt to jack.us.csv
# Converted pcg_g.us.txt to pcg_g.us.csv
# Converted ueps.us.txt to ueps.us.csv
# Converted nly_d.us.txt to nly_d.us.csv
# Converted grpn.us.txt to grpn.us.csv
# Converted scacw.us.txt to scacw.us.csv
# Converted xtlb.us.txt to xtlb.us.csv
# Converted jagx.us.txt to jagx.us.csv
# Converted ophc.us.txt to ophc.us.csv
# Converted psl.us.txt to psl.us.csv
# Converted lnc.us.txt to lnc.us.csv
# Converted ko.us.txt to ko.us.csv
# Converted mza.us.txt to mza.us.csv
# Converted cbfv.us.txt to cbfv.us.csv
# Converted clx.us.txt to clx.us.csv
# Converted hpt.us.txt to hpt.us.csv
# Converted mntx.us.txt to mntx.us.csv
# Converted nvta.us.txt to nvta.us.csv
# Converted chk.us.txt to chk.us.csv
# Converted xgtiw.us.txt to xgtiw.us.csv
# Converted blx.us.txt to blx.us.csv
# Converted bxp_b.us.txt to bxp_b.us.csv
# Converted mvcb.us.txt to mvcb.us.csv
# Converted x.us.txt to x.us.csv
# Converted lbrda.us.txt to lbrda.us.csv
# Converted emj.us.txt to emj.us.csv
# Converted bhk.us.txt to bhk.us.csv
# Converted itg.us.txt to itg.us.csv
# Converted jpm_h.us.txt to jpm_h.us.csv
# Converted rli.us.txt to rli.us.csv
# Converted spro.us.txt to spro.us.csv
# Converted titn.us.txt to titn.us.csv
# Converted hgh.us.txt to hgh.us.csv
# Converted ssnt.us.txt to ssnt.us.csv
# Converted thga.us.txt to thga.us.csv
# Converted nvgn.us.txt to nvgn.us.csv
# Converted asb_c.us.txt to asb_c.us.csv
# Converted apc.us.txt to apc.us.csv
# Converted min.us.txt to min.us.csv
# Converted atnx.us.txt to atnx.us.csv
# Converted aval.us.txt to aval.us.csv
# Converted ltrx.us.txt to ltrx.us.csv
# Converted ppr.us.txt to ppr.us.csv
# Converted mmlp.us.txt to mmlp.us.csv
# Converted ktcc.us.txt to ktcc.us.csv
# Converted banc_d.us.txt to banc_d.us.csv
# Converted gainn.us.txt to gainn.us.csv
# Converted siri.us.txt to siri.us.csv
# Converted dtea.us.txt to dtea.us.csv
# Converted lone.us.txt to lone.us.csv
# Converted agen.us.txt to agen.us.csv
# Converted sfbs.us.txt to sfbs.us.csv
# Converted hlm_.us.txt to hlm_.us.csv
# Converted dwlv.us.txt to dwlv.us.csv
# Converted avgo.us.txt to avgo.us.csv
# Converted dmtx.us.txt to dmtx.us.csv
# Converted iex.us.txt to iex.us.csv
# Converted hurc.us.txt to hurc.us.csv
# Converted semg.us.txt to semg.us.csv
# Converted redu.us.txt to redu.us.csv
# Converted arii.us.txt to arii.us.csv
# Converted chke.us.txt to chke.us.csv
# Converted gwr.us.txt to gwr.us.csv
# Converted thrm.us.txt to thrm.us.csv
# Converted wexp.us.txt to wexp.us.csv
# Converted sny.us.txt to sny.us.csv
# Converted evstc.us.txt to evstc.us.csv
# Converted qbak.us.txt to qbak.us.csv
# Converted wprt.us.txt to wprt.us.csv
# Converted aeo.us.txt to aeo.us.csv
# Converted angi.us.txt to angi.us.csv
# Converted nwe.us.txt to nwe.us.csv
# Converted resi.us.txt to resi.us.csv
# Converted sptl.us.txt to sptl.us.csv
# Converted kona.us.txt to kona.us.csv
# Converted intc.us.txt to intc.us.csv
# Converted pam.us.txt to pam.us.csv
# Converted alp_o-cl.us.txt to alp_o-cl.us.csv
# Converted bio-b.us.txt to bio-b.us.csv
# Converted asnd.us.txt to asnd.us.csv
# Converted numg.us.txt to numg.us.csv
# Converted c_j.us.txt to c_j.us.csv
# Converted iff.us.txt to iff.us.csv
# Converted smg.us.txt to smg.us.csv
# Converted vgr.us.txt to vgr.us.csv
# Converted nr.us.txt to nr.us.csv
# Converted cie.us.txt to cie.us.csv
# Converted plym.us.txt to plym.us.csv
# Converted htfa.us.txt to htfa.us.csv
# Converted abb.us.txt to abb.us.csv
# Converted gcp.us.txt to gcp.us.csv
# Converted oesx.us.txt to oesx.us.csv
# Converted tntr.us.txt to tntr.us.csv
# Converted pvac.us.txt to pvac.us.csv
# Converted spwr.us.txt to spwr.us.csv
# Converted glu_a.us.txt to glu_a.us.csv
# Converted skln.us.txt to skln.us.csv
# Converted rjf.us.txt to rjf.us.csv
# Converted per.us.txt to per.us.csv
# Converted kyo.us.txt to kyo.us.csv
# Converted urgn.us.txt to urgn.us.csv
# Converted sigi.us.txt to sigi.us.csv
# Converted gdl_b.us.txt to gdl_b.us.csv
# Converted paa.us.txt to paa.us.csv
# Converted aap.us.txt to aap.us.csv
# Converted gsbc.us.txt to gsbc.us.csv
# Converted form.us.txt to form.us.csv
# Converted cubi_e.us.txt to cubi_e.us.csv
# Converted mtb_.us.txt to mtb_.us.csv
# Converted dov.us.txt to dov.us.csv
# Converted jsml.us.txt to jsml.us.csv
# Converted gsm.us.txt to gsm.us.csv
# Converted qcrh.us.txt to qcrh.us.csv
# Converted ryi.us.txt to ryi.us.csv
# Converted ulbi.us.txt to ulbi.us.csv
# Converted ecol.us.txt to ecol.us.csv
# Converted lcut.us.txt to lcut.us.csv
# Converted iag.us.txt to iag.us.csv
# Converted fsm.us.txt to fsm.us.csv
# Converted kgji.us.txt to kgji.us.csv
# Converted nfec.us.txt to nfec.us.csv
# Converted enva.us.txt to enva.us.csv
# Converted vktx.us.txt to vktx.us.csv
# Converted ipay.us.txt to ipay.us.csv
# Converted trmb.us.txt to trmb.us.csv
# Converted spsm.us.txt to spsm.us.csv
# Converted nick.us.txt to nick.us.csv
# Converted ggo.us.txt to ggo.us.csv
# Converted jsyn.us.txt to jsyn.us.csv
# Converted pfl.us.txt to pfl.us.csv
# Converted xlnx.us.txt to xlnx.us.csv
# Converted lret.us.txt to lret.us.csv
# Converted cii.us.txt to cii.us.csv
# Converted usdp.us.txt to usdp.us.csv
# Converted six.us.txt to six.us.csv
# Converted plya.us.txt to plya.us.csv
# Converted pgem.us.txt to pgem.us.csv
# Converted kmm.us.txt to kmm.us.csv
# Converted heus.us.txt to heus.us.csv
# Converted kalv.us.txt to kalv.us.csv
# Converted nwfl.us.txt to nwfl.us.csv
# Converted gps.us.txt to gps.us.csv
# Converted expo.us.txt to expo.us.csv
# Converted mict.us.txt to mict.us.csv
# Converted jpeu.us.txt to jpeu.us.csv
# Converted nclh.us.txt to nclh.us.csv
# Converted jmm.us.txt to jmm.us.csv
# Converted homl.us.txt to homl.us.csv
# Converted sckt.us.txt to sckt.us.csv
# Converted linu.us.txt to linu.us.csv
# Converted fate.us.txt to fate.us.csv
# Converted infn.us.txt to infn.us.csv
# Converted gvp.us.txt to gvp.us.csv
# Converted ziop.us.txt to ziop.us.csv
# Converted hewc.us.txt to hewc.us.csv
# Converted grc.us.txt to grc.us.csv
# Converted dvmt.us.txt to dvmt.us.csv
# Converted bvxvw.us.txt to bvxvw.us.csv
# Converted husa.us.txt to husa.us.csv
# Converted bnft.us.txt to bnft.us.csv
# Converted veco.us.txt to veco.us.csv
# Converted frc.us.txt to frc.us.csv
# Converted qure.us.txt to qure.us.csv
# Converted mosy.us.txt to mosy.us.csv
# Converted ipci.us.txt to ipci.us.csv
# Converted nrt.us.txt to nrt.us.csv
# Converted skis.us.txt to skis.us.csv
# Converted enx.us.txt to enx.us.csv
# Converted clirw.us.txt to clirw.us.csv
# Converted wen.us.txt to wen.us.csv
# Converted isf.us.txt to isf.us.csv
# Converted brk-b.us.txt to brk-b.us.csv
# Converted lsxmb.us.txt to lsxmb.us.csv
# Converted nvg.us.txt to nvg.us.csv
# Converted spun.us.txt to spun.us.csv
# Converted adm.us.txt to adm.us.csv
# Converted ln.us.txt to ln.us.csv
# Converted batra.us.txt to batra.us.csv
# Converted wage.us.txt to wage.us.csv
# Converted igd.us.txt to igd.us.csv
# Converted nee_r.us.txt to nee_r.us.csv
# Converted jcom.us.txt to jcom.us.csv
# Converted cmcl.us.txt to cmcl.us.csv
# Converted vsar.us.txt to vsar.us.csv
# Converted obe.us.txt to obe.us.csv
# Converted wrls.us.txt to wrls.us.csv
# Converted ebio.us.txt to ebio.us.csv
# Converted fun.us.txt to fun.us.csv
# Converted xl.us.txt to xl.us.csv
# Converted apo.us.txt to apo.us.csv
# Converted qtm.us.txt to qtm.us.csv
# Converted ffty.us.txt to ffty.us.csv
# Converted axs_d.us.txt to axs_d.us.csv
# Converted gfa.us.txt to gfa.us.csv
# Converted wbc.us.txt to wbc.us.csv
# Converted t.us.txt to t.us.csv
# Converted emf.us.txt to emf.us.csv
# Converted gbr.us.txt to gbr.us.csv
# Converted jpm_d.us.txt to jpm_d.us.csv
# Converted pcq.us.txt to pcq.us.csv
# Converted htgc.us.txt to htgc.us.csv
# Converted omab.us.txt to omab.us.csv
# Converted fbr.us.txt to fbr.us.csv
# Converted dmf.us.txt to dmf.us.csv
# Converted pei_b.us.txt to pei_b.us.csv
# Converted gfnsl.us.txt to gfnsl.us.csv
# Converted splk.us.txt to splk.us.csv
# Converted bcv_a.us.txt to bcv_a.us.csv
# Converted gdv_g.us.txt to gdv_g.us.csv
# Converted hnp.us.txt to hnp.us.csv
# Converted icui.us.txt to icui.us.csv
# Converted prpo.us.txt to prpo.us.csv
# Converted cvo.us.txt to cvo.us.csv
# Converted merc.us.txt to merc.us.csv
# Converted nee_c-cl.us.txt to nee_c-cl.us.csv
# Converted acfc.us.txt to acfc.us.csv
# Converted auto.us.txt to auto.us.csv
# Converted rndm.us.txt to rndm.us.csv
# Converted jhmi.us.txt to jhmi.us.csv
# Converted fsacu.us.txt to fsacu.us.csv
# Converted bas.us.txt to bas.us.csv
# Converted edr.us.txt to edr.us.csv
# Converted trex.us.txt to trex.us.csv
# Converted ushy.us.txt to ushy.us.csv
# Converted smbk.us.txt to smbk.us.csv
# Converted mgnx.us.txt to mgnx.us.csv
# Converted bw.us.txt to bw.us.csv
# Converted rodm.us.txt to rodm.us.csv
# Converted cway.us.txt to cway.us.csv
# Converted tdc.us.txt to tdc.us.csv
# Converted atto.us.txt to atto.us.csv
# Converted sab.us.txt to sab.us.csv
# Converted jsynw.us.txt to jsynw.us.csv
# Converted ftag.us.txt to ftag.us.csv
# Converted shlm.us.txt to shlm.us.csv
# Converted ddr.us.txt to ddr.us.csv
# Converted lgcy.us.txt to lgcy.us.csv
# Converted pre_g.us.txt to pre_g.us.csv
# Converted oxbr.us.txt to oxbr.us.csv
# Converted vod.us.txt to vod.us.csv
# Converted prgs.us.txt to prgs.us.csv
# Converted esgg.us.txt to esgg.us.csv
# Converted zbk.us.txt to zbk.us.csv
# Converted lndc.us.txt to lndc.us.csv
# Converted cnfr.us.txt to cnfr.us.csv
# Converted rf.us.txt to rf.us.csv
# Converted ras_b.us.txt to ras_b.us.csv
# Converted zb_h.us.txt to zb_h.us.csv
# Converted ttph.us.txt to ttph.us.csv
# Converted hmn.us.txt to hmn.us.csv
# Converted mtbc.us.txt to mtbc.us.csv
# Converted bjri.us.txt to bjri.us.csv
# Converted ldos.us.txt to ldos.us.csv
# Converted aldx.us.txt to aldx.us.csv
# Converted egl.us.txt to egl.us.csv
# Converted cclp.us.txt to cclp.us.csv
# Converted snna.us.txt to snna.us.csv
# Converted lpg.us.txt to lpg.us.csv
# Converted cbm.us.txt to cbm.us.csv
# Converted cemb.us.txt to cemb.us.csv
# Converted mtt.us.txt to mtt.us.csv
# Converted shos.us.txt to shos.us.csv
# Converted faln.us.txt to faln.us.csv
# Converted hfbl.us.txt to hfbl.us.csv
# Converted sona.us.txt to sona.us.csv
# Converted ttgt.us.txt to ttgt.us.csv
# Converted rogs.us.txt to rogs.us.csv
# Converted gsjy.us.txt to gsjy.us.csv
# Converted ai.us.txt to ai.us.csv
# Converted vhi.us.txt to vhi.us.csv
# Converted klic.us.txt to klic.us.csv
# Converted andaw.us.txt to andaw.us.csv
# Converted hive.us.txt to hive.us.csv
# Converted flws.us.txt to flws.us.csv
# Converted nusc.us.txt to nusc.us.csv
# Converted etsy.us.txt to etsy.us.csv
# Converted bfit.us.txt to bfit.us.csv
# Converted newa.us.txt to newa.us.csv
# Converted gjh.us.txt to gjh.us.csv
# Converted cdor.us.txt to cdor.us.csv
# Converted bscp.us.txt to bscp.us.csv
# Converted jmba.us.txt to jmba.us.csv
# Converted bdn.us.txt to bdn.us.csv
# Converted vvpr.us.txt to vvpr.us.csv
# Converted nesr.us.txt to nesr.us.csv
# Converted iamxr.us.txt to iamxr.us.csv
# Converted mpacu.us.txt to mpacu.us.csv
# Converted aoi.us.txt to aoi.us.csv
# Converted ufcs.us.txt to ufcs.us.csv
# Converted cy.us.txt to cy.us.csv
# Converted ship.us.txt to ship.us.csv
# Converted key_i.us.txt to key_i.us.csv
# Converted obln.us.txt to obln.us.csv
# Converted rnr_c.us.txt to rnr_c.us.csv
# Converted bwa.us.txt to bwa.us.csv
# Converted arco.us.txt to arco.us.csv
# Converted wday.us.txt to wday.us.csv
# Converted bhlb.us.txt to bhlb.us.csv
# Converted cjjd.us.txt to cjjd.us.csv
# Converted bfs_c.us.txt to bfs_c.us.csv
# Converted pxd.us.txt to pxd.us.csv
# Converted lpth.us.txt to lpth.us.csv
# Converted ssc.us.txt to ssc.us.csv
# Converted rtnb.us.txt to rtnb.us.csv
# Converted axu.us.txt to axu.us.csv
# Converted blbd.us.txt to blbd.us.csv
# Converted swp.us.txt to swp.us.csv
# Converted icpt.us.txt to icpt.us.csv
# Converted fcre.us.txt to fcre.us.csv
# Converted trq.us.txt to trq.us.csv
# Converted petq.us.txt to petq.us.csv
# Converted krnt.us.txt to krnt.us.csv
# Converted synl.us.txt to synl.us.csv
# Converted hbmd.us.txt to hbmd.us.csv
# Converted ufs.us.txt to ufs.us.csv
# Converted ubnk.us.txt to ubnk.us.csv
# Converted kth.us.txt to kth.us.csv
# Converted twin.us.txt to twin.us.csv
# Converted gme.us.txt to gme.us.csv
# Converted wmt.us.txt to wmt.us.csv
# Converted rga.us.txt to rga.us.csv
# Converted psec.us.txt to psec.us.csv
# Converted bcc.us.txt to bcc.us.csv
# Converted ccc.us.txt to ccc.us.csv
# Converted htht.us.txt to htht.us.csv
# Converted fiv.us.txt to fiv.us.csv
# Converted hafc.us.txt to hafc.us.csv
# Converted wlfc.us.txt to wlfc.us.csv
# Converted sga.us.txt to sga.us.csv
# Converted tmus.us.txt to tmus.us.csv
# Converted hdlv.us.txt to hdlv.us.csv
# Converted chfn.us.txt to chfn.us.csv
# Converted bpl.us.txt to bpl.us.csv
# Converted rtn.us.txt to rtn.us.csv
# Converted wala.us.txt to wala.us.csv
# Converted flgb.us.txt to flgb.us.csv
# Converted nmr.us.txt to nmr.us.csv
# Converted stn.us.txt to stn.us.csv
# Converted avnw.us.txt to avnw.us.csv
# Converted atac.us.txt to atac.us.csv
# Converted itri.us.txt to itri.us.csv
# Converted oia.us.txt to oia.us.csv
# Converted cpl.us.txt to cpl.us.csv
# Converted splp_t.us.txt to splp_t.us.csv
# Converted bbt_d.us.txt to bbt_d.us.csv
# Converted fmcir.us.txt to fmcir.us.csv
# Converted hhs.us.txt to hhs.us.csv
# Converted cwst.us.txt to cwst.us.csv
# Converted rcom.us.txt to rcom.us.csv
# Converted ipoa-u.us.txt to ipoa-u.us.csv
# Converted mat.us.txt to mat.us.csv
# Converted ebay.us.txt to ebay.us.csv
# Converted ssfn.us.txt to ssfn.us.csv
# Converted sfhy.us.txt to sfhy.us.csv
# Converted hznp.us.txt to hznp.us.csv
# Converted ti.us.txt to ti.us.csv
# Converted afsi_a.us.txt to afsi_a.us.csv
# Converted rso.us.txt to rso.us.csv
# Converted arcc.us.txt to arcc.us.csv
# Converted dxpe.us.txt to dxpe.us.csv
# Converted ior.us.txt to ior.us.csv
# Converted leg.us.txt to leg.us.csv
# Converted ctxs.us.txt to ctxs.us.csv
# Converted gf.us.txt to gf.us.csv
# Converted litb.us.txt to litb.us.csv
# Converted nycb_u.us.txt to nycb_u.us.csv
# Converted bkepp.us.txt to bkepp.us.csv
# Converted dac.us.txt to dac.us.csv
# Converted smci.us.txt to smci.us.csv
# Converted lyts.us.txt to lyts.us.csv
# Converted mram.us.txt to mram.us.csv
# Converted pkg.us.txt to pkg.us.csv
# Converted eep.us.txt to eep.us.csv
# Converted simo.us.txt to simo.us.csv
# Converted anip.us.txt to anip.us.csv
# Converted newm.us.txt to newm.us.csv
# Converted manh.us.txt to manh.us.csv
# Converted fred.us.txt to fred.us.csv
# Converted pot.us.txt to pot.us.csv
# Converted kodk.us.txt to kodk.us.csv
# Converted gnw.us.txt to gnw.us.csv
# Converted stb.us.txt to stb.us.csv
# Converted lbtyk.us.txt to lbtyk.us.csv
# Converted virt.us.txt to virt.us.csv
# Converted webk.us.txt to webk.us.csv
# Converted tup.us.txt to tup.us.csv
# Converted bbt_h.us.txt to bbt_h.us.csv
# Converted cts.us.txt to cts.us.csv
# Converted bern.us.txt to bern.us.csv
# Converted xray.us.txt to xray.us.csv
# Converted dwaq.us.txt to dwaq.us.csv
# Converted sd.us.txt to sd.us.csv
# Converted irwd.us.txt to irwd.us.csv
# Converted nim.us.txt to nim.us.csv
# Converted tile.us.txt to tile.us.csv
# Converted ahpaw.us.txt to ahpaw.us.csv
# Converted evhc.us.txt to evhc.us.csv
# Converted trpx.us.txt to trpx.us.csv
# Converted eqr.us.txt to eqr.us.csv
# Converted fmi.us.txt to fmi.us.csv
# Converted jtd.us.txt to jtd.us.csv
# Converted ahh.us.txt to ahh.us.csv
# Converted dx.us.txt to dx.us.csv
# Converted cco.us.txt to cco.us.csv
# Converted btec.us.txt to btec.us.csv
# Converted luv.us.txt to luv.us.csv
# Converted nets.us.txt to nets.us.csv
# Converted bco.us.txt to bco.us.csv
# Converted pebo.us.txt to pebo.us.csv
# Converted cisn.us.txt to cisn.us.csv
# Converted rarx.us.txt to rarx.us.csv
# Converted ajx.us.txt to ajx.us.csv
# Converted cel.us.txt to cel.us.csv
# Converted san.us.txt to san.us.csv
# Converted fh.us.txt to fh.us.csv
# Converted ntra.us.txt to ntra.us.csv
# Converted kgrn.us.txt to kgrn.us.csv
# Converted bsbr.us.txt to bsbr.us.csv
# Converted bel.us.txt to bel.us.csv
# Converted jhme.us.txt to jhme.us.csv
# Converted bf-b.us.txt to bf-b.us.csv
# Converted nxr.us.txt to nxr.us.csv
# Converted cade.us.txt to cade.us.csv
# Converted krg.us.txt to krg.us.csv
# Converted olli.us.txt to olli.us.csv
# Converted ekso.us.txt to ekso.us.csv
# Converted tss.us.txt to tss.us.csv
# Converted wbai.us.txt to wbai.us.csv
# Converted cpsh.us.txt to cpsh.us.csv
# Converted stba.us.txt to stba.us.csv
# Converted ug.us.txt to ug.us.csv
# Converted cms_b.us.txt to cms_b.us.csv
# Converted nuan.us.txt to nuan.us.csv
# Converted casy.us.txt to casy.us.csv
# Converted gs_d.us.txt to gs_d.us.csv
# Converted splg.us.txt to splg.us.csv
# Converted lxfr.us.txt to lxfr.us.csv
# Converted cxdc.us.txt to cxdc.us.csv
# Converted dgicb.us.txt to dgicb.us.csv
# Converted mtx.us.txt to mtx.us.csv
# Converted ev.us.txt to ev.us.csv
# Converted cba.us.txt to cba.us.csv
# Converted strp.us.txt to strp.us.csv
# Converted ffic.us.txt to ffic.us.csv
# Converted ae.us.txt to ae.us.csv
# Converted cfr.us.txt to cfr.us.csv
# Converted aif.us.txt to aif.us.csv
# Converted cytr.us.txt to cytr.us.csv
# Converted vnet.us.txt to vnet.us.csv
# Converted msgn.us.txt to msgn.us.csv
# Converted spxe.us.txt to spxe.us.csv
# Converted pmd.us.txt to pmd.us.csv
# Converted cffi.us.txt to cffi.us.csv
# Converted bfr.us.txt to bfr.us.csv
# Converted slmbp.us.txt to slmbp.us.csv
# Converted mcd.us.txt to mcd.us.csv
# Converted bbva.us.txt to bbva.us.csv
# Converted olp.us.txt to olp.us.csv
# Converted wfc_y.us.txt to wfc_y.us.csv
# Converted wbbw.us.txt to wbbw.us.csv
# Converted frph.us.txt to frph.us.csv
# Converted veacw.us.txt to veacw.us.csv
# Converted wsbf.us.txt to wsbf.us.csv
# Converted inov.us.txt to inov.us.csv
# Converted bvxv.us.txt to bvxv.us.csv
# Converted rbin.us.txt to rbin.us.csv
# Converted eto.us.txt to eto.us.csv
# Converted nhc.us.txt to nhc.us.csv
# Converted true.us.txt to true.us.csv
# Converted tetf.us.txt to tetf.us.csv
# Converted dhvw.us.txt to dhvw.us.csv
# Converted mrbk.us.txt to mrbk.us.csv
# Converted fcfs.us.txt to fcfs.us.csv
# Converted ahp.us.txt to ahp.us.csv
# Converted tsco.us.txt to tsco.us.csv
# Converted mbfi.us.txt to mbfi.us.csv
# Converted sgu.us.txt to sgu.us.csv
# Converted dpst.us.txt to dpst.us.csv
# Converted bmra.us.txt to bmra.us.csv
# Converted trco.us.txt to trco.us.csv
# Converted aeri.us.txt to aeri.us.csv
# Converted wstl.us.txt to wstl.us.csv
# Converted clrbw.us.txt to clrbw.us.csv
# Converted gib.us.txt to gib.us.csv
# Converted mfa.us.txt to mfa.us.csv
# Converted hlt.us.txt to hlt.us.csv
# Converted stz.us.txt to stz.us.csv
# Converted omf.us.txt to omf.us.csv
# Converted ovas.us.txt to ovas.us.csv
# Converted spi.us.txt to spi.us.csv
# Converted laws.us.txt to laws.us.csv
# Converted agm_b.us.txt to agm_b.us.csv
# Converted ihg.us.txt to ihg.us.csv
# Converted onvi.us.txt to onvi.us.csv
# Converted ttac.us.txt to ttac.us.csv
# Converted brcd.us.txt to brcd.us.csv
# Converted whlrw.us.txt to whlrw.us.csv
# Converted chmi_a.us.txt to chmi_a.us.csv
# Converted sdpi.us.txt to sdpi.us.csv
# Converted qlys.us.txt to qlys.us.csv
# Converted pbfx.us.txt to pbfx.us.csv
# Converted cm.us.txt to cm.us.csv
# Converted mrc.us.txt to mrc.us.csv
# Converted pcbk.us.txt to pcbk.us.csv
# Converted albo.us.txt to albo.us.csv
# Converted tear.us.txt to tear.us.csv
# Converted pol.us.txt to pol.us.csv
# Converted mbvx.us.txt to mbvx.us.csv
# Converted pb.us.txt to pb.us.csv
# Converted ssw.us.txt to ssw.us.csv
# Converted jphf.us.txt to jphf.us.csv
# Converted csf.us.txt to csf.us.csv
# Converted nano.us.txt to nano.us.csv
# Converted uvv.us.txt to uvv.us.csv
# Converted sbfg.us.txt to sbfg.us.csv
# Converted caro.us.txt to caro.us.csv
# Converted spib.us.txt to spib.us.csv
# Converted cnacr.us.txt to cnacr.us.csv
# Converted evg.us.txt to evg.us.csv
# Converted bsf.us.txt to bsf.us.csv
# Converted clir.us.txt to clir.us.csv
# Converted hii.us.txt to hii.us.csv
# Converted ocsll.us.txt to ocsll.us.csv
# Converted ttf.us.txt to ttf.us.csv
# Converted jbn.us.txt to jbn.us.csv
# Converted drna.us.txt to drna.us.csv
# Converted divo.us.txt to divo.us.csv
# Converted stag.us.txt to stag.us.csv
# Converted utf.us.txt to utf.us.csv
# Converted epd.us.txt to epd.us.csv
# Converted boot.us.txt to boot.us.csv
# Converted iii.us.txt to iii.us.csv
# Converted cmre_c.us.txt to cmre_c.us.csv
# Converted arex.us.txt to arex.us.csv
# Converted gpre.us.txt to gpre.us.csv
# Converted etw.us.txt to etw.us.csv
# Converted esgs.us.txt to esgs.us.csv
# Converted dgx.us.txt to dgx.us.csv
# Converted tcfc.us.txt to tcfc.us.csv
# Converted tgi.us.txt to tgi.us.csv
# Converted sbh.us.txt to sbh.us.csv
# Converted ohai.us.txt to ohai.us.csv
# Converted scwx.us.txt to scwx.us.csv
# Converted akam.us.txt to akam.us.csv
# Converted bby.us.txt to bby.us.csv
# Converted ghl.us.txt to ghl.us.csv
# Converted syke.us.txt to syke.us.csv
# Converted ugi.us.txt to ugi.us.csv
# Converted flqd.us.txt to flqd.us.csv
# Converted jpih.us.txt to jpih.us.csv
# Converted oke.us.txt to oke.us.csv
# Converted rose.us.txt to rose.us.csv
# Converted sohoo.us.txt to sohoo.us.csv
# Converted crh.us.txt to crh.us.csv
# Converted ahl_c.us.txt to ahl_c.us.csv
# Converted jec.us.txt to jec.us.csv
# Converted twx.us.txt to twx.us.csv
# Converted hlne.us.txt to hlne.us.csv
# Converted nke.us.txt to nke.us.csv
# Converted kap.us.txt to kap.us.csv
# Converted pxlw.us.txt to pxlw.us.csv
# Converted tess.us.txt to tess.us.csv
# Converted flau.us.txt to flau.us.csv
# Converted nov.us.txt to nov.us.csv
# Converted alpn.us.txt to alpn.us.csv
# Converted oacqr.us.txt to oacqr.us.csv
# Converted ticcl.us.txt to ticcl.us.csv
# Converted sbgi.us.txt to sbgi.us.csv
# Converted logi.us.txt to logi.us.csv
# Converted pcty.us.txt to pcty.us.csv
# Converted tdw.us.txt to tdw.us.csv
# Converted cet.us.txt to cet.us.csv
# Converted ds_c.us.txt to ds_c.us.csv
# Converted bc.us.txt to bc.us.csv
# Converted msm.us.txt to msm.us.csv
# Converted amca.us.txt to amca.us.csv
# Converted cic-ws.us.txt to cic-ws.us.csv
# Converted see.us.txt to see.us.csv
# Converted cag.us.txt to cag.us.csv
# Converted lbix.us.txt to lbix.us.csv
# Converted itcb.us.txt to itcb.us.csv
# Converted ddf.us.txt to ddf.us.csv
# Converted lmrko.us.txt to lmrko.us.csv
# Converted once.us.txt to once.us.csv
# Converted edf.us.txt to edf.us.csv
# Converted rosew.us.txt to rosew.us.csv
# Converted nxj.us.txt to nxj.us.csv
# Converted auph.us.txt to auph.us.csv
# Converted ntrsp.us.txt to ntrsp.us.csv
# Converted bbu.us.txt to bbu.us.csv
# Converted wlb.us.txt to wlb.us.csv
# Converted psa_f.us.txt to psa_f.us.csv
# Converted aker.us.txt to aker.us.csv
# Converted ofg_a.us.txt to ofg_a.us.csv
# Converted qvca.us.txt to qvca.us.csv
# Converted flqh.us.txt to flqh.us.csv
# Converted msci.us.txt to msci.us.csv
# Converted mtl.us.txt to mtl.us.csv
# Converted cbu.us.txt to cbu.us.csv
# Converted nhld.us.txt to nhld.us.csv
# Converted adsk.us.txt to adsk.us.csv
# Converted aq.us.txt to aq.us.csv
# Converted fls.us.txt to fls.us.csv
# Converted air.us.txt to air.us.csv
# Converted bui.us.txt to bui.us.csv
# Converted hygs.us.txt to hygs.us.csv
# Converted nubd.us.txt to nubd.us.csv
# Converted chgx.us.txt to chgx.us.csv
# Converted mjco.us.txt to mjco.us.csv
# Converted rgco.us.txt to rgco.us.csv
# Converted cui.us.txt to cui.us.csv
# Converted hie.us.txt to hie.us.csv
# Converted old.us.txt to old.us.csv
# Converted kblm.us.txt to kblm.us.csv
# Converted aset.us.txt to aset.us.csv
# Converted buse.us.txt to buse.us.csv
# Converted lfgr.us.txt to lfgr.us.csv
# Converted jazz.us.txt to jazz.us.csv
# Converted stt_e.us.txt to stt_e.us.csv
# Converted twou.us.txt to twou.us.csv
# Converted bak.us.txt to bak.us.csv
# Converted rei.us.txt to rei.us.csv
# Converted msa.us.txt to msa.us.csv
# Converted hyt.us.txt to hyt.us.csv
# Converted jrs.us.txt to jrs.us.csv
# Converted usg.us.txt to usg.us.csv
# Converted fbss.us.txt to fbss.us.csv
# Converted qmom.us.txt to qmom.us.csv
# Converted uwt.us.txt to uwt.us.csv
# Converted swir.us.txt to swir.us.csv
# Converted casm.us.txt to casm.us.csv
# Converted mmac.us.txt to mmac.us.csv
# Converted esv.us.txt to esv.us.csv
# Converted clns.us.txt to clns.us.csv
# Converted tsg.us.txt to tsg.us.csv
# Converted cyccp.us.txt to cyccp.us.csv
# Converted jw-b.us.txt to jw-b.us.csv
# Converted cnet.us.txt to cnet.us.csv
# Converted xny.us.txt to xny.us.csv
# Converted bpt.us.txt to bpt.us.csv
# Converted sedg.us.txt to sedg.us.csv
# Converted lmnr.us.txt to lmnr.us.csv
# Converted nwhm.us.txt to nwhm.us.csv
# Converted btg.us.txt to btg.us.csv
# Converted cpt.us.txt to cpt.us.csv
# Converted hlx.us.txt to hlx.us.csv
# Converted mfm.us.txt to mfm.us.csv
# Converted issc.us.txt to issc.us.csv
# Converted ctg.us.txt to ctg.us.csv
# Converted sp.us.txt to sp.us.csv
# Converted fmci.us.txt to fmci.us.csv
# Converted imax.us.txt to imax.us.csv
# Converted spe.us.txt to spe.us.csv
# Converted nept.us.txt to nept.us.csv
# Converted bgh.us.txt to bgh.us.csv
# Converted ktp.us.txt to ktp.us.csv
# Converted ehic.us.txt to ehic.us.csv
# Converted synt.us.txt to synt.us.csv
# Converted lub.us.txt to lub.us.csv
# Converted trgp.us.txt to trgp.us.csv
# Converted chuy.us.txt to chuy.us.csv
# Converted phm.us.txt to phm.us.csv
# Converted hbio.us.txt to hbio.us.csv
# Converted msft.us.txt to msft.us.csv
# Converted prah.us.txt to prah.us.csv
# Converted sgy.us.txt to sgy.us.csv
# Converted dl.us.txt to dl.us.csv
# Converted jpc.us.txt to jpc.us.csv
# Converted alo.us.txt to alo.us.csv
# Converted wyn.us.txt to wyn.us.csv
# Converted arcw.us.txt to arcw.us.csv
# Converted lfus.us.txt to lfus.us.csv
# Converted uri.us.txt to uri.us.csv
# Converted evk.us.txt to evk.us.csv
# Converted sbbx.us.txt to sbbx.us.csv
# Converted pn.us.txt to pn.us.csv
# Converted ssbi.us.txt to ssbi.us.csv
# Converted tri.us.txt to tri.us.csv
# Converted nyh.us.txt to nyh.us.csv
# Converted qada.us.txt to qada.us.csv
# Converted gjp.us.txt to gjp.us.csv
# Converted kkr_b.us.txt to kkr_b.us.csv
# Converted slgn.us.txt to slgn.us.csv
# Converted chscn.us.txt to chscn.us.csv
# Converted gnc.us.txt to gnc.us.csv
# Converted frac.us.txt to frac.us.csv
# Converted kwn.us.txt to kwn.us.csv
# Converted iccc.us.txt to iccc.us.csv
# Converted nycb_a.us.txt to nycb_a.us.csv
# Converted cnsf.us.txt to cnsf.us.csv
# Converted rxdx.us.txt to rxdx.us.csv
# Converted dd_b.us.txt to dd_b.us.csv
# Converted wern.us.txt to wern.us.csv
# Converted plpm.us.txt to plpm.us.csv
# Converted ca.us.txt to ca.us.csv
# Converted mro.us.txt to mro.us.csv
# Converted ambc.us.txt to ambc.us.csv
# Converted fsac.us.txt to fsac.us.csv
# Converted jwn.us.txt to jwn.us.csv
# Converted tsq.us.txt to tsq.us.csv
# Converted crr.us.txt to crr.us.csv
# Converted ue.us.txt to ue.us.csv
# Converted salt.us.txt to salt.us.csv
# Converted clne.us.txt to clne.us.csv
# Converted mrsn.us.txt to mrsn.us.csv
# Converted fmao.us.txt to fmao.us.csv
# Converted src.us.txt to src.us.csv
# Converted cva.us.txt to cva.us.csv
# Converted rvp.us.txt to rvp.us.csv
# Converted key.us.txt to key.us.csv
# Converted rrc.us.txt to rrc.us.csv
# Converted by.us.txt to by.us.csv
# Converted discb.us.txt to discb.us.csv
# Converted cen.us.txt to cen.us.csv
# Converted hyb.us.txt to hyb.us.csv
# Converted sal.us.txt to sal.us.csv
# Converted ftai.us.txt to ftai.us.csv
# Converted elec.us.txt to elec.us.csv
# Converted pre_i.us.txt to pre_i.us.csv
# Converted imtb.us.txt to imtb.us.csv
# Converted ben.us.txt to ben.us.csv
# Converted tedu.us.txt to tedu.us.csv
# Converted nxp.us.txt to nxp.us.csv
# Converted silc.us.txt to silc.us.csv
# Converted xlrn.us.txt to xlrn.us.csv
# Converted rmpl_.us.txt to rmpl_.us.csv
# Converted bwxt.us.txt to bwxt.us.csv
# Converted smrt.us.txt to smrt.us.csv
# Converted rh.us.txt to rh.us.csv
# Converted mcf.us.txt to mcf.us.csv
# Converted sun.us.txt to sun.us.csv
# Converted jbt.us.txt to jbt.us.csv
# Converted mgu.us.txt to mgu.us.csv
# Converted veacu.us.txt to veacu.us.csv
# Converted tnp_e.us.txt to tnp_e.us.csv
# Converted sov_c.us.txt to sov_c.us.csv
# Converted fihd.us.txt to fihd.us.csv
# Converted wair.us.txt to wair.us.csv
# Converted akrx.us.txt to akrx.us.csv
# Converted etm.us.txt to etm.us.csv
# Converted nha.us.txt to nha.us.csv
# Converted glop.us.txt to glop.us.csv
# Converted run.us.txt to run.us.csv
# Converted mbcn.us.txt to mbcn.us.csv
# Converted mtz.us.txt to mtz.us.csv
# Converted cim_a.us.txt to cim_a.us.csv
# Converted hdmv.us.txt to hdmv.us.csv
# Converted vlt.us.txt to vlt.us.csv
# Converted ag.us.txt to ag.us.csv
# Converted mlqd.us.txt to mlqd.us.csv
# Converted sbr.us.txt to sbr.us.csv
# Converted tgs.us.txt to tgs.us.csv
# Converted hemv.us.txt to hemv.us.csv
# Converted bbc.us.txt to bbc.us.csv
# Converted ainc.us.txt to ainc.us.csv
# Converted pmf.us.txt to pmf.us.csv
# Converted whg.us.txt to whg.us.csv
# Converted lpi.us.txt to lpi.us.csv
# Converted rbs_s.us.txt to rbs_s.us.csv
# Converted gd.us.txt to gd.us.csv
# Converted tap.us.txt to tap.us.csv
# Converted cw.us.txt to cw.us.csv
# Converted hxl.us.txt to hxl.us.csv
# Converted aspn.us.txt to aspn.us.csv
# Converted kndi.us.txt to kndi.us.csv
# Converted pke.us.txt to pke.us.csv
# Converted uec.us.txt to uec.us.csv
# Converted rnem.us.txt to rnem.us.csv
# Converted taxr.us.txt to taxr.us.csv
# Converted onb.us.txt to onb.us.csv
# Converted mav.us.txt to mav.us.csv
# Converted px.us.txt to px.us.csv
# Converted nsec.us.txt to nsec.us.csv
# Skipping accp.us.txt as it is empty.
# Converted tk.us.txt to tk.us.csv
# Converted ern.us.txt to ern.us.csv
# Converted afsi_c.us.txt to afsi_c.us.csv
# Converted evol.us.txt to evol.us.csv
# Converted lee.us.txt to lee.us.csv
# Converted scvl.us.txt to scvl.us.csv
# Converted plse.us.txt to plse.us.csv
# Converted fsbk.us.txt to fsbk.us.csv
# Converted nrcib.us.txt to nrcib.us.csv
# Converted vii.us.txt to vii.us.csv
# Converted lens.us.txt to lens.us.csv
# Converted fix.us.txt to fix.us.csv
# Converted ccm.us.txt to ccm.us.csv
# Converted jone.us.txt to jone.us.csv
# Converted snoa.us.txt to snoa.us.csv
# Converted ktf.us.txt to ktf.us.csv
# Converted ccmp.us.txt to ccmp.us.csv
# Converted frbk.us.txt to frbk.us.csv
# Converted sgy-ws.us.txt to sgy-ws.us.csv
# Converted alex.us.txt to alex.us.csv
# Converted efl.us.txt to efl.us.csv
# Converted vive.us.txt to vive.us.csv
# Converted cpb.us.txt to cpb.us.csv
# Converted scap.us.txt to scap.us.csv
# Converted wu.us.txt to wu.us.csv
# Converted sand.us.txt to sand.us.csv
# Converted duc.us.txt to duc.us.csv
# Converted dish.us.txt to dish.us.csv
# Converted race.us.txt to race.us.csv
# Converted sf.us.txt to sf.us.csv
# Converted dwas.us.txt to dwas.us.csv
# Converted ahpau.us.txt to ahpau.us.csv
# Converted all_b.us.txt to all_b.us.csv
# Converted nnn.us.txt to nnn.us.csv
# Converted laz.us.txt to laz.us.csv
# Converted mdso.us.txt to mdso.us.csv
# Converted arcm.us.txt to arcm.us.csv
# Converted agii.us.txt to agii.us.csv
# Converted fcvt.us.txt to fcvt.us.csv
# Converted kirk.us.txt to kirk.us.csv
# Converted xom.us.txt to xom.us.csv
# Converted mrrl.us.txt to mrrl.us.csv
# Converted meso.us.txt to meso.us.csv
# Converted trs.us.txt to trs.us.csv
# Converted mei.us.txt to mei.us.csv
# Converted tg.us.txt to tg.us.csv
# Converted pets.us.txt to pets.us.csv
# Converted nusa.us.txt to nusa.us.csv
# Converted pki.us.txt to pki.us.csv
# Converted supn.us.txt to supn.us.csv
# Converted bscr.us.txt to bscr.us.csv
# Converted gbli.us.txt to gbli.us.csv
# Converted bdl.us.txt to bdl.us.csv
# Converted pdco.us.txt to pdco.us.csv
# Converted mpacw.us.txt to mpacw.us.csv
# Converted usmf.us.txt to usmf.us.csv
# Converted wpxp.us.txt to wpxp.us.csv
# Converted mvf.us.txt to mvf.us.csv
# Converted hsni.us.txt to hsni.us.csv
# Converted ksu_.us.txt to ksu_.us.csv
# Converted cdl.us.txt to cdl.us.csv
# Converted teo.us.txt to teo.us.csv
# Converted mxim.us.txt to mxim.us.csv
# Converted uqm.us.txt to uqm.us.csv
# Converted sbfgp.us.txt to sbfgp.us.csv
# Converted obor.us.txt to obor.us.csv
# Converted apog.us.txt to apog.us.csv
# Converted stl.us.txt to stl.us.csv
# Converted icsh.us.txt to icsh.us.csv
# Converted wy.us.txt to wy.us.csv
# Converted ncbs.us.txt to ncbs.us.csv
# Converted gtyh.us.txt to gtyh.us.csv
# Converted cpn.us.txt to cpn.us.csv
# Converted bbt_f.us.txt to bbt_f.us.csv
# Converted omp.us.txt to omp.us.csv
# Skipping amrh.us.txt as it is empty.
# Converted adap.us.txt to adap.us.csv
# Converted pld.us.txt to pld.us.csv
# Converted bgr.us.txt to bgr.us.csv
# Converted cof-ws.us.txt to cof-ws.us.csv
# Converted ebs.us.txt to ebs.us.csv
# Converted mitt_b.us.txt to mitt_b.us.csv
# Converted gene.us.txt to gene.us.csv
# Converted rgc.us.txt to rgc.us.csv
# Converted panw.us.txt to panw.us.csv
# Converted amag.us.txt to amag.us.csv
# Converted oasi.us.txt to oasi.us.csv
# Converted taho.us.txt to taho.us.csv
# Converted gcow.us.txt to gcow.us.csv
# Converted cbio.us.txt to cbio.us.csv
# Converted blvd.us.txt to blvd.us.csv
# Converted cca.us.txt to cca.us.csv
# Converted mux.us.txt to mux.us.csv
# Converted fit.us.txt to fit.us.csv
# Converted tbb.us.txt to tbb.us.csv
# Converted sgc.us.txt to sgc.us.csv
# Converted arql.us.txt to arql.us.csv
# Converted ryam_a.us.txt to ryam_a.us.csv
# Converted nuro.us.txt to nuro.us.csv
# Converted res.us.txt to res.us.csv
# Converted fsacw.us.txt to fsacw.us.csv
# Converted oncs.us.txt to oncs.us.csv
# Converted corr.us.txt to corr.us.csv
# Converted lgf-a.us.txt to lgf-a.us.csv
# Converted gsie.us.txt to gsie.us.csv
# Converted tda.us.txt to tda.us.csv
# Converted rave.us.txt to rave.us.csv
# Converted jri.us.txt to jri.us.csv
# Converted jsynu.us.txt to jsynu.us.csv
# Converted cyhhz.us.txt to cyhhz.us.csv
# Converted ff.us.txt to ff.us.csv
# Converted shlo.us.txt to shlo.us.csv
# Converted bwl-a.us.txt to bwl-a.us.csv
# Converted rivr.us.txt to rivr.us.csv
# Converted gs_j.us.txt to gs_j.us.csv
# Converted esl.us.txt to esl.us.csv
# Converted frsx.us.txt to frsx.us.csv
# Converted bmch.us.txt to bmch.us.csv
# Converted jmpb.us.txt to jmpb.us.csv
# Converted uwn.us.txt to uwn.us.csv
# Converted ntes.us.txt to ntes.us.csv
# Converted twn.us.txt to twn.us.csv
# Converted brqs.us.txt to brqs.us.csv
# Converted dsl.us.txt to dsl.us.csv
# Converted ndaq.us.txt to ndaq.us.csv
# Converted nakd.us.txt to nakd.us.csv
# Converted cvm.us.txt to cvm.us.csv
# Converted ctib.us.txt to ctib.us.csv
# Converted psdo.us.txt to psdo.us.csv
# Converted piy.us.txt to piy.us.csv
# Converted egn.us.txt to egn.us.csv
# Converted smed.us.txt to smed.us.csv
# Converted cbo.us.txt to cbo.us.csv
# Converted sfm.us.txt to sfm.us.csv
# Converted agm-a.us.txt to agm-a.us.csv
# Converted sonc.us.txt to sonc.us.csv
# Converted andau.us.txt to andau.us.csv
# Converted epr.us.txt to epr.us.csv
# Converted tcbil.us.txt to tcbil.us.csv
# Converted kffb.us.txt to kffb.us.csv
# Converted esge.us.txt to esge.us.csv
# Converted mhla.us.txt to mhla.us.csv
# Converted pcsb.us.txt to pcsb.us.csv
# Converted yin.us.txt to yin.us.csv
# Converted time.us.txt to time.us.csv
# Converted prss.us.txt to prss.us.csv
# Converted azre.us.txt to azre.us.csv
# Converted ttp.us.txt to ttp.us.csv
# Skipping vist.us.txt as it is empty.
# Converted amsf.us.txt to amsf.us.csv
# Converted ohrp.us.txt to ohrp.us.csv
# Converted wfc_w.us.txt to wfc_w.us.csv
# Converted divy.us.txt to divy.us.csv
# Converted xin.us.txt to xin.us.csv
# Converted tpc.us.txt to tpc.us.csv
# Converted ufi.us.txt to ufi.us.csv
# Converted efx.us.txt to efx.us.csv
# Converted gil.us.txt to gil.us.csv
# Converted nete.us.txt to nete.us.csv
# Converted ladr.us.txt to ladr.us.csv
# Converted pho.us.txt to pho.us.csv
# Converted nnn_f.us.txt to nnn_f.us.csv
# Converted zagg.us.txt to zagg.us.csv
# Converted ardx.us.txt to ardx.us.csv
# Converted xcem.us.txt to xcem.us.csv
# Converted bte.us.txt to bte.us.csv
# Converted bont.us.txt to bont.us.csv
# Converted aaon.us.txt to aaon.us.csv
# Converted bles.us.txt to bles.us.csv
# Converted mfo.us.txt to mfo.us.csv
# Converted stt.us.txt to stt.us.csv
# Converted nail.us.txt to nail.us.csv
# Converted sr.us.txt to sr.us.csv
# Converted tctl.us.txt to tctl.us.csv
# Converted spg.us.txt to spg.us.csv
# Converted gjr.us.txt to gjr.us.csv
# Converted bfin.us.txt to bfin.us.csv
# Converted chscl.us.txt to chscl.us.csv
# Converted supv.us.txt to supv.us.csv
# Converted ddr_k.us.txt to ddr_k.us.csv
# Converted ircp.us.txt to ircp.us.csv
# Converted abtx.us.txt to abtx.us.csv
# Converted tlrd.us.txt to tlrd.us.csv
# Converted lpcn.us.txt to lpcn.us.csv
# Converted fcap.us.txt to fcap.us.csv
# Converted aos.us.txt to aos.us.csv
# Converted amba.us.txt to amba.us.csv
# Converted cc.us.txt to cc.us.csv
# Converted pglc.us.txt to pglc.us.csv
# Converted wbs_e.us.txt to wbs_e.us.csv
# Converted efoi.us.txt to efoi.us.csv
# Converted cara.us.txt to cara.us.csv
# Converted rgen.us.txt to rgen.us.csv
# Converted codx.us.txt to codx.us.csv
# Converted spil.us.txt to spil.us.csv
# Converted giga.us.txt to giga.us.csv
# Converted mdwd.us.txt to mdwd.us.csv
# Converted abcd.us.txt to abcd.us.csv
# Converted evi.us.txt to evi.us.csv
# Converted mab.us.txt to mab.us.csv
# Converted ssy.us.txt to ssy.us.csv
# Converted else.us.txt to else.us.csv
# Converted ovbc.us.txt to ovbc.us.csv
# Converted smtc.us.txt to smtc.us.csv
# Converted mini.us.txt to mini.us.csv
# Converted rore.us.txt to rore.us.csv
# Converted osle.us.txt to osle.us.csv
# Converted trk.us.txt to trk.us.csv
# Converted swj.us.txt to swj.us.csv
# Converted pphmp.us.txt to pphmp.us.csv
# Converted rqi.us.txt to rqi.us.csv
# Converted chci.us.txt to chci.us.csv
# Converted kfs.us.txt to kfs.us.csv
# Converted pzn.us.txt to pzn.us.csv
# Converted catb.us.txt to catb.us.csv
# Converted gprk.us.txt to gprk.us.csv
# Converted ety.us.txt to ety.us.csv
# Converted rely.us.txt to rely.us.csv
# Converted cuk.us.txt to cuk.us.csv
# Converted hig.us.txt to hig.us.csv
# Converted mbtf.us.txt to mbtf.us.csv
# Converted mcr.us.txt to mcr.us.csv
# Converted dty.us.txt to dty.us.csv
# Converted mga.us.txt to mga.us.csv
# Converted wfc_o.us.txt to wfc_o.us.csv
# Converted diva.us.txt to diva.us.csv
# Converted sgyp.us.txt to sgyp.us.csv
# Converted bbw.us.txt to bbw.us.csv
# Converted geos.us.txt to geos.us.csv
# Converted hbhc.us.txt to hbhc.us.csv
# Converted psa_d.us.txt to psa_d.us.csv
# Converted glq.us.txt to glq.us.csv
# Converted two_a.us.txt to two_a.us.csv
# Converted bac_l.us.txt to bac_l.us.csv
# Converted dare.us.txt to dare.us.csv
# Converted unvr.us.txt to unvr.us.csv
# Converted hchc.us.txt to hchc.us.csv
# Converted ffiu.us.txt to ffiu.us.csv
# Converted mtn.us.txt to mtn.us.csv
# Converted fhb.us.txt to fhb.us.csv
# Converted amc.us.txt to amc.us.csv
# Converted cof_c.us.txt to cof_c.us.csv
# Converted hclp.us.txt to hclp.us.csv
# Converted ebtc.us.txt to ebtc.us.csv
# Converted drys.us.txt to drys.us.csv
# Converted ncty.us.txt to ncty.us.csv
# Converted srce.us.txt to srce.us.csv
# Converted nee_h-cl.us.txt to nee_h-cl.us.csv
# Converted kem.us.txt to kem.us.csv
# Converted bold.us.txt to bold.us.csv
# Converted crf.us.txt to crf.us.csv
# Converted tse.us.txt to tse.us.csv
# Converted cvu.us.txt to cvu.us.csv
# Converted ftva.us.txt to ftva.us.csv
# Converted arr_b.us.txt to arr_b.us.csv
# Converted dst.us.txt to dst.us.csv
# Converted myov.us.txt to myov.us.csv
# Converted stl_a.us.txt to stl_a.us.csv
# Converted alco.us.txt to alco.us.csv
# Converted stt_g.us.txt to stt_g.us.csv
# Converted grmn.us.txt to grmn.us.csv
# Converted vly_a.us.txt to vly_a.us.csv
# Converted twow.us.txt to twow.us.csv
# Converted jhms.us.txt to jhms.us.csv
# Converted gbil.us.txt to gbil.us.csv
# Converted ppln.us.txt to ppln.us.csv
# Converted tdy.us.txt to tdy.us.csv
# Converted bpmp.us.txt to bpmp.us.csv
# Converted attu.us.txt to attu.us.csv
# Converted lnth.us.txt to lnth.us.csv
# Converted cez.us.txt to cez.us.csv
# Converted cai.us.txt to cai.us.csv
# Converted qnst.us.txt to qnst.us.csv
# Converted tcx.us.txt to tcx.us.csv
# Converted nw_c-cl.us.txt to nw_c-cl.us.csv
# Converted mgic.us.txt to mgic.us.csv
# Converted ixys.us.txt to ixys.us.csv
# Converted jqc.us.txt to jqc.us.csv
# Converted mtb.us.txt to mtb.us.csv
# Converted fhn.us.txt to fhn.us.csv
# Converted el.us.txt to el.us.csv
# Converted avxs.us.txt to avxs.us.csv
# Converted govni.us.txt to govni.us.csv
# Converted dci.us.txt to dci.us.csv
# Converted akao.us.txt to akao.us.csv
# Converted amswa.us.txt to amswa.us.csv
# Converted pdex.us.txt to pdex.us.csv
# Converted sbsi.us.txt to sbsi.us.csv
# Converted wll.us.txt to wll.us.csv
# Converted pim.us.txt to pim.us.csv
# Converted hwbk.us.txt to hwbk.us.csv
# Converted wttr.us.txt to wttr.us.csv
# Converted rp.us.txt to rp.us.csv
# Converted fmbi.us.txt to fmbi.us.csv
# Converted ttd.us.txt to ttd.us.csv
# Converted vc.us.txt to vc.us.csv
# Converted mgm.us.txt to mgm.us.csv
# Converted jbl.us.txt to jbl.us.csv
# Converted egif.us.txt to egif.us.csv
# Converted kemq.us.txt to kemq.us.csv
# Converted etfc.us.txt to etfc.us.csv
# Converted pdvw.us.txt to pdvw.us.csv
# Converted bcrh.us.txt to bcrh.us.csv
# Converted abax.us.txt to abax.us.csv
# Converted frta.us.txt to frta.us.csv
# Converted ht_c.us.txt to ht_c.us.csv
# Converted keys.us.txt to keys.us.csv
# Converted cev.us.txt to cev.us.csv
# Converted ba.us.txt to ba.us.csv
# Converted ebsb.us.txt to ebsb.us.csv
# Converted cae.us.txt to cae.us.csv
# Converted ddd.us.txt to ddd.us.csv
# Converted amgp.us.txt to amgp.us.csv
# ...
# Converted kio.us.txt to kio.us.csv
# Converted ncz.us.txt to ncz.us.csv
# Converted uevm.us.txt to uevm.us.csv
# Converted apam.us.txt to apam.us.csv
# Converted htus.us.txt to htus.us.csv
# Converted frc_d.us.txt to frc_d.us.csv
# Converted clbs.us.txt to clbs.us.csv
# Converted avdl.us.txt to avdl.us.csv
# Converted lind.us.txt to lind.us.csv
# Converted cnit.us.txt to cnit.us.csv
# Converted glpi.us.txt to glpi.us.csv
# Converted dhil.us.txt to dhil.us.csv
# Converted chk_d.us.txt to chk_d.us.csv
# Converted mfem.us.txt to mfem.us.csv
# Converted hees.us.txt to hees.us.csv
# Converted bsmx.us.txt to bsmx.us.csv
# Converted vsto.us.txt to vsto.us.csv
# Converted eog.us.txt to eog.us.csv
# Converted pagp.us.txt to pagp.us.csv
# Converted dkt.us.txt to dkt.us.csv
# Converted clrb.us.txt to clrb.us.csv
# Converted mxl.us.txt to mxl.us.csv
# Converted ewre.us.txt to ewre.us.csv
# Converted sjw.us.txt to sjw.us.csv
# Converted osk.us.txt to osk.us.csv
# Converted kura.us.txt to kura.us.csv
# Converted aer.us.txt to aer.us.csv
# Converted snd.us.txt to snd.us.csv
# Converted ylde.us.txt to ylde.us.csv
# Converted gcbc.us.txt to gcbc.us.csv
# Converted wsm.us.txt to wsm.us.csv
# Converted avgr.us.txt to avgr.us.csv
# Converted nspr-ws.us.txt to nspr-ws.us.csv
# Converted nvec.us.txt to nvec.us.csv
# Converted jnpr.us.txt to jnpr.us.csv
# Converted vsm.us.txt to vsm.us.csv
# Converted syx.us.txt to syx.us.csv
# Converted mkc.us.txt to mkc.us.csv
# Converted nee_c.us.txt to nee_c.us.csv
# Converted skys.us.txt to skys.us.csv
# Converted arow.us.txt to arow.us.csv
# Converted esio.us.txt to esio.us.csv
# Converted nfg.us.txt to nfg.us.csv
# Converted gern.us.txt to gern.us.csv
# Converted ssni.us.txt to ssni.us.csv
# Converted nvgs.us.txt to nvgs.us.csv
# Converted jha.us.txt to jha.us.csv
# Converted rfil.us.txt to rfil.us.csv
# Converted adnt.us.txt to adnt.us.csv
# Converted cetv.us.txt to cetv.us.csv
# Converted ms_e.us.txt to ms_e.us.csv
# Converted ofg.us.txt to ofg.us.csv
# Converted iboc.us.txt to iboc.us.csv
# Converted e.us.txt to e.us.csv
# Converted cmpr.us.txt to cmpr.us.csv
# Converted ipi.us.txt to ipi.us.csv
# Converted ble.us.txt to ble.us.csv
# Converted paas.us.txt to paas.us.csv
# Converted cmta.us.txt to cmta.us.csv
# Converted agro.us.txt to agro.us.csv
# Converted mdlz.us.txt to mdlz.us.csv
# Converted bhv.us.txt to bhv.us.csv
# Converted clpr.us.txt to clpr.us.csv
# Converted kr.us.txt to kr.us.csv
# Converted hpi.us.txt to hpi.us.csv
# Converted shg.us.txt to shg.us.csv
# Converted brqsw.us.txt to brqsw.us.csv
# Converted fbc.us.txt to fbc.us.csv
# Converted oa.us.txt to oa.us.csv
# Converted htz.us.txt to htz.us.csv
# Converted ablx.us.txt to ablx.us.csv
# Converted gva.us.txt to gva.us.csv
# Skipping bxg.us.txt as it is empty.
# Converted lmfa.us.txt to lmfa.us.csv
# Converted grr.us.txt to grr.us.csv
# Converted ggz_a.us.txt to ggz_a.us.csv
# Converted nyrt.us.txt to nyrt.us.csv
# Converted ivfvc.us.txt to ivfvc.us.csv
# Converted epr_e.us.txt to epr_e.us.csv
# Converted mexx.us.txt to mexx.us.csv
# Converted amza.us.txt to amza.us.csv
# Converted sabr.us.txt to sabr.us.csv
# Converted nxrt.us.txt to nxrt.us.csv
# Converted xbio.us.txt to xbio.us.csv
# Converted bracw.us.txt to bracw.us.csv
# Converted jobs.us.txt to jobs.us.csv
# Converted sybt.us.txt to sybt.us.csv
# Converted fnsr.us.txt to fnsr.us.csv
# Converted nre.us.txt to nre.us.csv
# Converted oilk.us.txt to oilk.us.csv
# Converted bkh.us.txt to bkh.us.csv
# Converted pdm.us.txt to pdm.us.csv
# Converted wal.us.txt to wal.us.csv
# Converted gen.us.txt to gen.us.csv
# Converted lyb.us.txt to lyb.us.csv
# Converted dni.us.txt to dni.us.csv
# Converted ckh.us.txt to ckh.us.csv
# Converted euxl.us.txt to euxl.us.csv
# Converted idmo.us.txt to idmo.us.csv
# Converted hl.us.txt to hl.us.csv
# Converted fen.us.txt to fen.us.csv
# Converted nodk.us.txt to nodk.us.csv
# Converted cptag.us.txt to cptag.us.csv
# Converted sky.us.txt to sky.us.csv
# Converted hpe.us.txt to hpe.us.csv
# Converted cli.us.txt to cli.us.csv
# Converted usap.us.txt to usap.us.csv
# Converted tact.us.txt to tact.us.csv
# Converted agn.us.txt to agn.us.csv
# Converted spvm.us.txt to spvm.us.csv
# Converted i.us.txt to i.us.csv
# Converted tcf_c.us.txt to tcf_c.us.csv
# Converted moti.us.txt to moti.us.csv
# Converted mfcb.us.txt to mfcb.us.csv
# Converted ajxa.us.txt to ajxa.us.csv
# Converted entl.us.txt to entl.us.csv
# Converted ms_i.us.txt to ms_i.us.csv
# Converted atni.us.txt to atni.us.csv
# Converted ssw_g.us.txt to ssw_g.us.csv
# Converted btu_.us.txt to btu_.us.csv
# Converted eric.us.txt to eric.us.csv
# Converted mlhr.us.txt to mlhr.us.csv
# Converted oksb.us.txt to oksb.us.csv
# Converted ppc.us.txt to ppc.us.csv
# Converted srne.us.txt to srne.us.csv
# Converted clns_g.us.txt to clns_g.us.csv
# Converted dzsi.us.txt to dzsi.us.csv
# Converted ticc.us.txt to ticc.us.csv
# Converted adp.us.txt to adp.us.csv
# Converted meoh.us.txt to meoh.us.csv
# Converted ori.us.txt to ori.us.csv
# Converted myrg.us.txt to myrg.us.csv
# Converted hcap.us.txt to hcap.us.csv
# Converted shbi.us.txt to shbi.us.csv
# Converted myn.us.txt to myn.us.csv
# Converted sybx.us.txt to sybx.us.csv
# Converted wes.us.txt to wes.us.csv
# Converted cys_a.us.txt to cys_a.us.csv
# Converted bkd.us.txt to bkd.us.csv
# Converted ljpc.us.txt to ljpc.us.csv
# Converted unt.us.txt to unt.us.csv
# Converted urbn.us.txt to urbn.us.csv
# Converted geb.us.txt to geb.us.csv
# Converted schw_b.us.txt to schw_b.us.csv
# Converted hfxj.us.txt to hfxj.us.csv
# Converted nvda.us.txt to nvda.us.csv
# Converted xelb.us.txt to xelb.us.csv
# Converted safm.us.txt to safm.us.csv
# Converted mnr.us.txt to mnr.us.csv
# Converted jks.us.txt to jks.us.csv
# Converted blmn.us.txt to blmn.us.csv
# Converted mara.us.txt to mara.us.csv
# Converted neu.us.txt to neu.us.csv
# Converted bofi.us.txt to bofi.us.csv
# Converted hesm.us.txt to hesm.us.csv
# Converted edom.us.txt to edom.us.csv
# Converted oge.us.txt to oge.us.csv
# Converted frc_h.us.txt to frc_h.us.csv
# Converted jpeh.us.txt to jpeh.us.csv
# Converted jmp.us.txt to jmp.us.csv
# Converted aaap.us.txt to aaap.us.csv
# Converted wbib.us.txt to wbib.us.csv
# Converted xbks.us.txt to xbks.us.csv
# Converted vtl.us.txt to vtl.us.csv
# Converted hstm.us.txt to hstm.us.csv
# Converted auo.us.txt to auo.us.csv
# Converted ibd.us.txt to ibd.us.csv
# Converted numv.us.txt to numv.us.csv
# Converted gpn.us.txt to gpn.us.csv
# Converted expr.us.txt to expr.us.csv
# Converted ncv.us.txt to ncv.us.csv
# Converted sngxw.us.txt to sngxw.us.csv
# Converted efbi.us.txt to efbi.us.csv
# Converted rlj_a.us.txt to rlj_a.us.csv
# Converted cit.us.txt to cit.us.csv
# Converted opy.us.txt to opy.us.csv
# Converted nc.us.txt to nc.us.csv
# Converted hjpx.us.txt to hjpx.us.csv
# Converted thw.us.txt to thw.us.csv
# Converted cmg.us.txt to cmg.us.csv
# Converted amkr.us.txt to amkr.us.csv
# Converted dhf.us.txt to dhf.us.csv
# Converted vrsn.us.txt to vrsn.us.csv
# Converted jp.us.txt to jp.us.csv
# Converted mtbcp.us.txt to mtbcp.us.csv
# Converted pbb.us.txt to pbb.us.csv
# Converted aprn.us.txt to aprn.us.csv
# Converted bit.us.txt to bit.us.csv
# Converted snak.us.txt to snak.us.csv
# Converted elu.us.txt to elu.us.csv
# Converted tril.us.txt to tril.us.csv
# Converted vwr.us.txt to vwr.us.csv
# Converted fsp.us.txt to fsp.us.csv
# Converted schw.us.txt to schw.us.csv
# Converted midd.us.txt to midd.us.csv
# Converted hei.us.txt to hei.us.csv
# Converted asix.us.txt to asix.us.csv
# Converted syt.us.txt to syt.us.csv
# Converted ally_a.us.txt to ally_a.us.csv
# Converted grub.us.txt to grub.us.csv
# Converted armk.us.txt to armk.us.csv
# Converted cswi.us.txt to cswi.us.csv
# Converted mzor.us.txt to mzor.us.csv
# Converted wwr.us.txt to wwr.us.csv
# Converted mxdu.us.txt to mxdu.us.csv
# Converted mbot.us.txt to mbot.us.csv
# Converted osg.us.txt to osg.us.csv
# Converted egrx.us.txt to egrx.us.csv
# Converted snh.us.txt to snh.us.csv
# Converted blvdu.us.txt to blvdu.us.csv
# Converted pnc_q.us.txt to pnc_q.us.csv
# Converted peo.us.txt to peo.us.csv
# Converted evri.us.txt to evri.us.csv
# Converted bny.us.txt to bny.us.csv
# Converted cfnb.us.txt to cfnb.us.csv
# Converted celgz.us.txt to celgz.us.csv
# Converted gdl.us.txt to gdl.us.csv
# Converted tivo.us.txt to tivo.us.csv
# Converted yrd.us.txt to yrd.us.csv
# Converted rmniw.us.txt to rmniw.us.csv
# Converted irdmb.us.txt to irdmb.us.csv
# Converted ast.us.txt to ast.us.csv
# Converted rtec.us.txt to rtec.us.csv
# Converted sti_a.us.txt to sti_a.us.csv
# Converted ftxg.us.txt to ftxg.us.csv
# Converted jemd.us.txt to jemd.us.csv
# Converted nem.us.txt to nem.us.csv
# Converted bxs.us.txt to bxs.us.csv
# Converted grf.us.txt to grf.us.csv
# Converted mrns.us.txt to mrns.us.csv
# Converted skm.us.txt to skm.us.csv
# Converted hx.us.txt to hx.us.csv
# Converted coo.us.txt to coo.us.csv
# Converted hsc.us.txt to hsc.us.csv
# Converted smhd.us.txt to smhd.us.csv
# Converted trow.us.txt to trow.us.csv
# Converted canf.us.txt to canf.us.csv
# Converted oeur.us.txt to oeur.us.csv
# Converted appf.us.txt to appf.us.csv
# Converted kmda.us.txt to kmda.us.csv
# Converted lyv.us.txt to lyv.us.csv
# Converted sce_d.us.txt to sce_d.us.csv
# Converted zixi.us.txt to zixi.us.csv
# Converted mmt.us.txt to mmt.us.csv
# Converted acor.us.txt to acor.us.csv
# Converted ofs.us.txt to ofs.us.csv
# Converted ltrpa.us.txt to ltrpa.us.csv
# Converted aroc.us.txt to aroc.us.csv
# Converted apopw.us.txt to apopw.us.csv
# Converted iga.us.txt to iga.us.csv
# Converted pcyo.us.txt to pcyo.us.csv
# Converted snsr.us.txt to snsr.us.csv
# Converted cohn.us.txt to cohn.us.csv
# Converted wvfc.us.txt to wvfc.us.csv
# Converted lmt.us.txt to lmt.us.csv
# Converted pth.us.txt to pth.us.csv
# Converted icow.us.txt to icow.us.csv
# Converted vbf.us.txt to vbf.us.csv
# Converted kf.us.txt to kf.us.csv
# Converted xpl.us.txt to xpl.us.csv
# Converted ry_s-cl.us.txt to ry_s-cl.us.csv
# Converted dfs_b-cl.us.txt to dfs_b-cl.us.csv
# Converted mbio.us.txt to mbio.us.csv
# Converted bcom.us.txt to bcom.us.csv
# Converted eip.us.txt to eip.us.csv
# Converted nymtn.us.txt to nymtn.us.csv
# Converted q.us.txt to q.us.csv
# Converted igeb.us.txt to igeb.us.csv
# Converted spvu.us.txt to spvu.us.csv
# Converted tipt.us.txt to tipt.us.csv
# Converted type.us.txt to type.us.csv
# Converted bhb.us.txt to bhb.us.csv
# Converted wrb_b.us.txt to wrb_b.us.csv
# Converted wmgiz.us.txt to wmgiz.us.csv
# Converted jpm_a.us.txt to jpm_a.us.csv
# Converted nextw.us.txt to nextw.us.csv
# Converted aau.us.txt to aau.us.csv
# Converted cna.us.txt to cna.us.csv
# Converted snp.us.txt to snp.us.csv
# Converted nwl.us.txt to nwl.us.csv
# Converted irm.us.txt to irm.us.csv
# Converted pacw.us.txt to pacw.us.csv
# Converted lvhi.us.txt to lvhi.us.csv
# Converted eos.us.txt to eos.us.csv
# Converted rnp.us.txt to rnp.us.csv
# Converted heq.us.txt to heq.us.csv
# Converted bncl.us.txt to bncl.us.csv
# Converted mod.us.txt to mod.us.csv
# Converted qrvo.us.txt to qrvo.us.csv
# Converted hei-a.us.txt to hei-a.us.csv
# Converted odc.us.txt to odc.us.csv
# Converted sach.us.txt to sach.us.csv
# Converted osbc.us.txt to osbc.us.csv
# Converted golf.us.txt to golf.us.csv
# Converted ctrp.us.txt to ctrp.us.csv
# Converted prk.us.txt to prk.us.csv
# Converted patk.us.txt to patk.us.csv
# Converted gsh.us.txt to gsh.us.csv
# Converted orbc.us.txt to orbc.us.csv
# Converted daio.us.txt to daio.us.csv
# Converted xshd.us.txt to xshd.us.csv
# Converted tho.us.txt to tho.us.csv
# Converted corr_a.us.txt to corr_a.us.csv
# Converted cuba.us.txt to cuba.us.csv
# Converted hall.us.txt to hall.us.csv
# Converted san_i.us.txt to san_i.us.csv
# Converted cil.us.txt to cil.us.csv
# Converted veru.us.txt to veru.us.csv
# Converted psb_x.us.txt to psb_x.us.csv
# Converted rmcf.us.txt to rmcf.us.csv
# Converted insg.us.txt to insg.us.csv
# Converted ubp_f-cl.us.txt to ubp_f-cl.us.csv
# Converted pfi.us.txt to pfi.us.csv
# Converted mhi.us.txt to mhi.us.csv
# Converted vpg.us.txt to vpg.us.csv
# Converted nfbk.us.txt to nfbk.us.csv
# Converted ocn.us.txt to ocn.us.csv
# Converted thff.us.txt to thff.us.csv
# Converted rvlt.us.txt to rvlt.us.csv
# Converted crto.us.txt to crto.us.csv
# Converted wpg.us.txt to wpg.us.csv
# Converted psxp.us.txt to psxp.us.csv
# Skipping mapi.us.txt as it is empty.
# Converted gte.us.txt to gte.us.csv
# Converted wtt.us.txt to wtt.us.csv
# Converted ehth.us.txt to ehth.us.csv
# Converted heuv.us.txt to heuv.us.csv
# Converted c_c.us.txt to c_c.us.csv
# Converted sito.us.txt to sito.us.csv
# Converted gsd.us.txt to gsd.us.csv
# Converted exc.us.txt to exc.us.csv
# Converted gww.us.txt to gww.us.csv
# Converted evar.us.txt to evar.us.csv
# Converted moh.us.txt to moh.us.csv
# Converted dxc.us.txt to dxc.us.csv
# Converted oflx.us.txt to oflx.us.csv
# Converted hdrw.us.txt to hdrw.us.csv
# Converted xel.us.txt to xel.us.csv
# Converted lvhe.us.txt to lvhe.us.csv
# Converted fisv.us.txt to fisv.us.csv
# Converted ibmk.us.txt to ibmk.us.csv
# Converted ivr.us.txt to ivr.us.csv
# Converted nss.us.txt to nss.us.csv
# Converted pfbi.us.txt to pfbi.us.csv
# Converted ctas.us.txt to ctas.us.csv
# Converted pah.us.txt to pah.us.csv
# Converted fdx.us.txt to fdx.us.csv
# Converted dkl.us.txt to dkl.us.csv
# Converted ford.us.txt to ford.us.csv
# Converted jnce.us.txt to jnce.us.csv
# Converted gladn.us.txt to gladn.us.csv
# Converted flir.us.txt to flir.us.csv
# Converted bdxa.us.txt to bdxa.us.csv
# Converted ibp.us.txt to ibp.us.csv
# Converted arna.us.txt to arna.us.csv
# Converted regn.us.txt to regn.us.csv
# Converted ncb.us.txt to ncb.us.csv
# Converted scon.us.txt to scon.us.csv
# Converted fti.us.txt to fti.us.csv
# Converted mhe.us.txt to mhe.us.csv
# Converted hbp.us.txt to hbp.us.csv
# Converted home.us.txt to home.us.csv
# Converted atos.us.txt to atos.us.csv
# Converted plnt.us.txt to plnt.us.csv
# Converted bgsf.us.txt to bgsf.us.csv
# Converted hfc.us.txt to hfc.us.csv
# Converted asna.us.txt to asna.us.csv
# Converted rlgy.us.txt to rlgy.us.csv
# Converted trmk.us.txt to trmk.us.csv
# Converted reta.us.txt to reta.us.csv
# Converted rbus.us.txt to rbus.us.csv
# Converted bms.us.txt to bms.us.csv
# Skipping ehr.us.txt as it is empty.
# Converted ptnr.us.txt to ptnr.us.csv
# Converted pfe.us.txt to pfe.us.csv
# Converted thc.us.txt to thc.us.csv
# Converted rso_b.us.txt to rso_b.us.csv
# Converted aft.us.txt to aft.us.csv
# Converted nati.us.txt to nati.us.csv
# Converted dla.us.txt to dla.us.csv
# Converted psb_t.us.txt to psb_t.us.csv
# Converted tlp.us.txt to tlp.us.csv
# Converted bwinb.us.txt to bwinb.us.csv
# Converted bdc_b.us.txt to bdc_b.us.csv
# Converted abg.us.txt to abg.us.csv
# Converted cms.us.txt to cms.us.csv
# Converted dhr.us.txt to dhr.us.csv
# Converted gsat.us.txt to gsat.us.csv
# Converted jd.us.txt to jd.us.csv
# Converted tenx.us.txt to tenx.us.csv
# Converted sce_h.us.txt to sce_h.us.csv
# Converted lsxmk.us.txt to lsxmk.us.csv
# Converted orpn.us.txt to orpn.us.csv
# Converted wat.us.txt to wat.us.csv
# Converted tlys.us.txt to tlys.us.csv
# Converted tgp_a.us.txt to tgp_a.us.csv
# Converted sor.us.txt to sor.us.csv
# Converted elon.us.txt to elon.us.csv
# Converted ahgp.us.txt to ahgp.us.csv
# Converted sb_b.us.txt to sb_b.us.csv
# Converted ooma.us.txt to ooma.us.csv
# Converted ht.us.txt to ht.us.csv
# Converted rxn.us.txt to rxn.us.csv
# Converted ontxw.us.txt to ontxw.us.csv
# Converted pcg_b.us.txt to pcg_b.us.csv
# Converted tpge-u.us.txt to tpge-u.us.csv
# Converted nea.us.txt to nea.us.csv
# Converted fitbi.us.txt to fitbi.us.csv
# Converted dwin.us.txt to dwin.us.csv
# Converted asx.us.txt to asx.us.csv
# Converted dplo.us.txt to dplo.us.csv
# Converted faro.us.txt to faro.us.csv
# Converted wpg_h.us.txt to wpg_h.us.csv
# Converted awk.us.txt to awk.us.csv
# Converted hds.us.txt to hds.us.csv
# Converted fwonk.us.txt to fwonk.us.csv
# Converted crvs.us.txt to crvs.us.csv
# Converted ltea.us.txt to ltea.us.csv
# Converted mtls.us.txt to mtls.us.csv
# Converted ns_b.us.txt to ns_b.us.csv
# Converted camt.us.txt to camt.us.csv
# Converted emo.us.txt to emo.us.csv
# Converted hpq.us.txt to hpq.us.csv
# Converted pirs.us.txt to pirs.us.csv
# Converted ival.us.txt to ival.us.csv
# Converted chn.us.txt to chn.us.csv
# Converted omex.us.txt to omex.us.csv
# Converted roic.us.txt to roic.us.csv
# Converted dmo.us.txt to dmo.us.csv
# Converted uzb.us.txt to uzb.us.csv
# Converted nbl.us.txt to nbl.us.csv
# Converted nrim.us.txt to nrim.us.csv
# Converted lmat.us.txt to lmat.us.csv
# Converted atu.us.txt to atu.us.csv
# Converted jhy.us.txt to jhy.us.csv
# Converted xco.us.txt to xco.us.csv
# Converted mik.us.txt to mik.us.csv
# Converted apf.us.txt to apf.us.csv
# Conversion completed!

# %% [markdown]
# Here is what a CSV File shoud look like
#
# 1. **Date**: The trading date for the stock data.
#
# 2. **Open**: The price at which the stock started trading for the day.
#
# 3. **High**: The highest price the stock reached during the trading day.
#
# 4. **Low**: The lowest price the stock reached during the trading day.
#
# 5. **Close**: The final price of the stock at the end of the trading day.
#
# 6. **Volume**: The total number of shares traded during the day.
#
# 7. **OpenInt (Open Interest)**: Commonly used in options and futures, it represents the total number of outstanding contracts that have not been settled.
#
# 8. **Daily Return (%)**: The percentage change in the stock’s closing price from the previous day’s close, calculated as:
#    \[
#    \text{Daily Return} = \frac{\text{Close} - \text{Previous Close}}{\text{Previous Close}} \times 100
#    \]
#
# 9. **Moving Average (MA-5, MA-10, MA-20)**: The average of the closing prices over a set period of days (5, 10, or 20). Moving averages help smooth out price data to identify trends.
#
# 10. **EMA (Exponential Moving Average)**: Similar to a simple moving average but gives more weight to recent prices, making it more responsive to new information.
#
# 11. **Bollinger Bands (BB_upper, BB_lower)**: Bands plotted above and below a moving average, typically two standard deviations away, used to assess price volatility. The upper band is the moving average + 2 standard deviations, and the lower band is the moving average - 2 standard deviations.
#
# 12. **Volatility-10**: A measure of the stock's price variation over a 10-day period, often calculated as the standard deviation of daily returns over this period.
#
# 13. **RSI (Relative Strength Index)**: A momentum oscillator that measures the speed and change of price movements, typically over a 14-day period, and ranges from 0 to 100. It’s used to identify overbought or oversold conditions.
#
# 14. **Volume Moving Average (Volume MA-20)**: The average volume traded over the past 20 days, helping identify changes in trading activity.
#
# 15. **High-Low (%)**: The percentage difference between the high and low prices of the day, calculated as:
#     \[
#     \frac{\text{High} - \text{Low}}{\text{Low}} \times 100
#     \]
#
# 16. **Close-Open (%)**: The percentage difference between the closing and opening prices of the day, calculated as:
#     \[
#     \frac{\text{Close} - \text{Open}}{\text{Open}} \times 100
#     \]
#
# 17. **Rate of Change over 10 days (ROC-10)**: The percentage change in price compared to the price 10 days ago, indicating momentum over this period.
#
# 18. **P/B Ratio (Price-to-Book Ratio)**: The ratio of a stock’s market price to its book value, indicating whether it’s undervalued or overvalued compared to its actual asset value.
#
# 19. **P/E Ratio (Price-to-Earnings Ratio)**: The ratio of a stock’s current price to its earnings per share (EPS), commonly used to assess valuation relative to earnings.
#
# 20. **Log Returns**: The logarithmic return of the stock price, calculated as:
#     \[
#     \ln\left(\frac{\text{Close}}{\text{Previous Close}}\right)
#     \]
#     Log returns are useful for analyzing continuous compounding over time.
#
# 21. **Dividend Yield**: The ratio of a company’s annual dividend payments to its share price, expressed as a percentage. It indicates the return on investment from dividends alone.
#
# 22. **Sector**: The industry sector to which the stock belongs (e.g., Technology, Healthcare), useful for sector-based analysis or comparisons.
#
# **Example**:
#
# | Date       | Open   | High   | Low    | Close  | Volume | OpenInt | Daily Return (%) | MA-5 | MA-10 | MA-20 | EMA  | BB_upper | BB_lower | Volatility-10 | RSI  | Volume MA-20 | High-Low (%) | Close-Open (%) | ROC-10 | P/B Ratio | P/E Ratio | Log Returns | Dividend Yield | Sector      |
# |------------|--------|--------|--------|--------|--------|---------|------------------|------|-------|-------|------|----------|----------|---------------|------|---------------|--------------|----------------|--------|-----------|-----------|-------------|----------------|-------------|
# | 1970-01-02 | 2.2972 | 2.3178 | 2.2972 | 2.2972 | 26437  | 0       | 0.0              | 2.3  | 2.3   | 2.3   | 2.3  | 2.5      | 2.1      | 0.02          | 50.0 | 26500         | 0.88         | 0.44           | 0.10   | 1.2       | 15.0      | 0.00        | 3.0%           | Technology  |
# | 1970-01-03 | 2.3100 | 2.3200 | 2.3000 | 2.3100 | 30000  | 0       | 0.56             | 2.31 | 2.31  | 2.31  | 2.31 | 2.6      | 2.2      | 0.03          | 52.0 | 27000         | 0.86         | 0.43           | 0.15   | 1.3       | 16.0      | 0.01        | 3.2%           | Technology  |
